# %% [markdown]
# <a href="https://colab.research.google.com/github/Technight27/Python-Codes-Data-Science/blob/main/Aug_23_DS_Day_7_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
plt.plot([5,3,8,7])
plt.show()

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,4

# %%
plt.plot([5,3,8,7])
plt.show()

# %%
plt.plot([2,4,6,8,10],[1,2,1.5,5,3])
plt.show()

# %%
x  = [2,4,6,8,10]
y = [1,2,1.5,5,3]
plt.plot (x,y)
plt.title ('First Graph')
plt.xlabel ('Month ')
plt.ylabel ('Sales')
plt.show()

# %%
np.arange (0,16,2)
# Out:
# array([ 0,  2,  4,  6,  8, 10, 12, 14])

# %%
[x1**2 for x1 in x]
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196]

# %%
x= np.arange (0,16,2)
plt.plot(x, [x1**2 for x1 in x])
plt.show()

# %%
x= np.arange (0,16,2)
plt.plot(x, [x1 for x1 in x])
plt.plot(x, [x1**2 for x1 in x])
plt.plot(x, [x1**3 for x1 in x])
plt.show()

# %%
14 *14*14
# Out:
# 2744

# %%
x= np.arange (0,100,2)
plt.plot(x, [x1 for x1 in x])
plt.plot(x, [x1**2 for x1 in x])
plt.plot(x, [x1**3 for x1 in x])
plt.show()

# %%
x= np.arange (0,100,2)
plt.plot(x, [x1 for x1 in x])
plt.plot(x, [x1**2 for x1 in x])
plt.plot(x, [x1**3 for x1 in x])
plt.axis ([0,20,0,80])
plt.show()

# %%
x= np.arange (0,100,2)
plt.plot(x, [x1 for x1 in x])
plt.plot(x, [x1**2 for x1 in x])
plt.plot(x, [x1**3 for x1 in x])
plt.axis ([100,150,150,200])
plt.show()
